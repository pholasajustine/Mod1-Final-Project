# %%
import json
from pandas import json_normalize
import pandas as pd
from datetime import date

# %% [markdown]
# Nous avons plusieurs fichiers dans lesquelles sont listées les offres d'alternances (provenant de l'api la bonne alternance). En effet, nous étions limitées à un rayon kilométrique de 200km. Nous avons donc dû en sortir plusieurs par rapport à différents points de la France pour essayer de couvrir la totalité du territoire.

# %%
with open("Data/nord.json", "r", encoding="utf-8") as read_file:
    data_nord = json.load(read_file)
with open("Data/nord_est.json", "r", encoding="utf-8") as read_file:
    data_nord_est = json.load(read_file)
with open("Data/nord-ouest.json", "r", encoding="utf-8") as read_file:
    data_nord_ouest = json.load(read_file)
with open("Data/centre.json", "r", encoding="utf-8") as read_file:
    data_centre = json.load(read_file)
with open("Data/sud_est.json", "r", encoding="utf-8") as read_file:
    data_sud_est = json.load(read_file)
with open("Data/sud_ouest.json", "r", encoding="utf-8") as read_file:
    data_sud_ouest = json.load(read_file)

# %%
data_centre.keys()
# Out:
# dict_keys(['peJobs', 'lbaCompanies', 'lbbCompanies'])

# %% [markdown]
# peJobs : les offres d'emploir provenant de pôle emploi
#
# lbaCompanies : les offres d'emploi provenant de la bonna alternance
#
# lbbCompanies : les offres d'emploi provenant de la bonne boîte

# %% [markdown]
# On utilise ici que les données provenant de peJobs car les autres source ne donne pas la date de création de l'offre, nous ne pourrions donc pas recouper ces données avec les données covid par date.

# %%
df_list = []

#On concaténe les différents listes d'offres d'emploi provenant des différents fichiers

df_list.append(json_normalize(data_centre['peJobs']['results']))

df_list.append(json_normalize(data_nord_est['peJobs']['results']))

df_list.append(json_normalize(data_nord_ouest['peJobs']['results']))

df_list.append(json_normalize(data_sud_est['peJobs']['results']))

df_list.append(json_normalize(data_sud_ouest['peJobs']['results']))

df_list.append(json_normalize(data_nord['peJobs']['results']))

jobs_df = pd.concat(df_list, axis=0)

jobs_df
# Out:
#    ideaType  ideaWeight                                              title  \
# 0     peJob      1000.0       coiffeur/coiffeuse en alternance (CAP) (H/F)
# 1     peJob      1000.0                               Coiffeur / Coiffeuse
# 2     peJob      1000.0  UN ALTERNANT - CHARGE DE PROJET FORMATION DIGI...
# 3     peJob      1000.0      Préparateur / Préparatrice de commandes (H/F)
# 4     peJob      1000.0      Agent / Agente logistique en magasinage (H/F)
# ..      ...         ...                                                ...
# 95    peJob       444.4  Conseiller / Conseillère en organisation d'évè...
# 96    peJob       311.8  UN ALTERNANT - CHARGE DE PROJET FORMATION DIGI...
# 97    peJob       100.0                 Assistant Social Media Manager H/F
# 98    peJob       100.0           Alternance - Attaché de presse F/H (H/F)
# 99    peJob       100.0        Alternant chargé de communication F/H (H/F)
#
#    longTitle    id diplomaLevel diploma   cfd rncpCode rncpLabel  ...  \
# 0       None  None         None    None  None     None      None  ...
# 1       None  None         None    None  None     None      None  ...
# 2       None  None         None    None  None     None      None  ...
# 3       None  None         None    None  None     None      None  ...
# 4       None  None         None    None  None     None      None  ...
# ..       ...   ...          ...     ...   ...      ...       ...  ...
# 95      None  None         None    None  None     None      None  ...
# 96      None  None         None    None  None     None      None  ...
# 97      None  None         None    None  None     None      None  ...
# 98      None  None         None    None  None     None      None  ...
# 99      None  None         None    None  None     None      None  ...
#
#                                       job.description job.contractType  \
# 0   salon FRANCK PROVOSTsitué en plein centre vill...              CDD
# 1   Apprenti (e) coiffeur (se)\nSuivant modalités ...              CDD
# 2   Dans ce cadre, vous serez amené(e) à :\n\nPart...              CDD
# 3   Description du poste :\nSTEF recrute pour sa f...              CDD
# 4   Description du poste :\nSTEF recrute pour sa f...              CDD
# ..                                                ...              ...
# 95  POSTE : Assistant Événementiel H/F\nPROFIL : E...              CDD
# 96  Dans ce cadre, vous serez amené(e) à :\n\nPart...              CDD
# 97  Le secteur du tourisme vous passionne et vous ...              CDD
# 98  Vous avez envie de contribuer à la promotion d...              CDD
# 99  Acteur de référence des services immobilier ré...              CDD
#
#                  job.contractDescription            job.duration  \
# 0   Contrat à durée déterminée - 24 Mois   35H Travail le samedi
# 1   Contrat à durée déterminée - 24 Mois    35H Horaires normaux
# 2   Contrat à durée déterminée - 24 Mois    35H Horaires normaux
# 3   Contrat à durée déterminée - 12 Mois                     NaN
# 4   Contrat à durée déterminée - 12 Mois                     NaN
# ..                                   ...                     ...
# 95  Contrat à durée déterminée - 12 Mois                     NaN
# 96  Contrat à durée déterminée - 24 Mois    35H Horaires normaux
# 97  Contrat à durée déterminée - 12 Mois        Horaires normaux
# 98  Contrat à durée déterminée - 12 Mois        Horaires normaux
# 99  Contrat à durée déterminée - 12 Mois  35 H  Horaires normaux
#
#            contact.name                                       contact.info  \
# 0                   NaN                                                NaN
# 1   Pôle Emploi Arpajon  2 ROUTE d'Egly\n91290 ARPAJON\nPour postuler, ...
# 2                   NaN  https://sanofi.wd3.myworkdayjobs.com/StudentPr...
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 95                  NaN                                                NaN
# 96                  NaN  https://sanofi.wd3.myworkdayjobs.com/StudentPr...
# 97                  NaN                                                NaN
# 98                  NaN                                                NaN
# 99                  NaN                                                NaN
#
#    contact contact.email company.description  company.logo
# 0      NaN           NaN                 NaN           NaN
# 1      NaN           NaN                 NaN           NaN
# 2      NaN           NaN                 NaN           NaN
# 3      NaN           NaN                 NaN           NaN
# 4      NaN           NaN                 NaN           NaN
# ..     ...           ...                 ...           ...
# 95     NaN           NaN                 NaN           NaN
# 96     NaN           NaN                 NaN           NaN
# 97     NaN           NaN                 NaN           NaN
# 98     NaN           NaN                 NaN           NaN
# 99     NaN           NaN                 NaN           NaN
#
# [518 rows x 39 columns]

# %%
jobs_df[['job.creationDate','title','place.city','company.name','place.latitude', 'place.longitude' ]]
# Out:
#             job.creationDate  \
# 0   2021-04-06T14:08:56.000Z
# 1   2021-02-04T17:25:49.000Z
# 2   2021-04-08T15:55:42.000Z
# 3   2021-03-21T08:59:42.000Z
# 4   2021-03-22T17:45:11.000Z
# ..                       ...
# 95  2021-03-24T03:12:02.000Z
# 96  2021-04-08T15:55:42.000Z
# 97  2021-04-08T06:20:42.000Z
# 98  2021-04-10T10:56:35.000Z
# 99  2021-03-24T07:45:52.000Z
#
#                                                 title  \
# 0        coiffeur/coiffeuse en alternance (CAP) (H/F)
# 1                                Coiffeur / Coiffeuse
# 2   UN ALTERNANT - CHARGE DE PROJET FORMATION DIGI...
# 3       Préparateur / Préparatrice de commandes (H/F)
# 4       Agent / Agente logistique en magasinage (H/F)
# ..                                                ...
# 95  Conseiller / Conseillère en organisation d'évè...
# 96  UN ALTERNANT - CHARGE DE PROJET FORMATION DIGI...
# 97                 Assistant Social Media Manager H/F
# 98           Alternance - Attaché de presse F/H (H/F)
# 99        Alternant chargé de communication F/H (H/F)
#
#                  place.city           company.name  place.latitude  \
# 0            91 - MONTGERON         FRANCK PROVOST       48.704816
# 1          91 - OLLAINVILLE   Salon des terrasses        48.599400
# 2   69 - NEUVILLE SUR SAONE  SANOFI-AVENTIS GROUPE       45.878996
# 3           91 - ATHIS MONS                    NaN       48.708960
# 4           91 - ATHIS MONS                    NaN       48.708960
# ..                      ...                    ...             ...
# 95         44 - ST HERBLAIN                    NaN       47.211390
# 96  69 - NEUVILLE SUR SAONE  SANOFI-AVENTIS GROUPE       45.878996
# 97            75 - PARIS 19                    NaN        2.345581
# 98            75 - PARIS 19                    NaN        2.345581
# 99            75 - PARIS 08                    NaN        2.345581
#
#     place.longitude
# 0          2.455399
# 1          2.227350
# 2          4.838026
# 3          2.384591
# 4          2.384591
# ..              ...
# 95        -1.651111
# 96         4.838026
# 97        48.859295
# 98        48.859295
# 99        48.859295
#
# [518 rows x 6 columns]

# %% [markdown]
# Le fichier covid n'ayant pas la donnée par ville, on va ajouter les départements pour pouvoir faire le lien par département.

# %%
def get_department(x):
    return((x[:2]))

jobs_df['place.departement'] = jobs_df['place.zipCode'].apply(str).apply(get_department)

# %% [markdown]
# Pour comparer avec le taux d'incidence covid par mois, on ajoute une colonne moi dans le dataframe

# %%
def get_month(x):
    return(x[0:7])

jobs_df['month'] = jobs_df['job.creationDate'].apply(get_month)

# %%
jobs_df.sort_values(by='month').head(3)
# Out:
#    ideaType  ideaWeight                                   title longTitle  \
# 34    peJob      1000.0       Agent d'élevage laitier F-H (H/F)      None
# 65    peJob      1000.0       Agent d'élevage laitier F-H (H/F)      None
# 80    peJob      1000.0  Agent d'élevage bovin viande F-H (H/F)      None
#
#       id diplomaLevel diploma   cfd rncpCode rncpLabel  ...  \
# 34  None         None    None  None     None      None  ...
# 65  None         None    None  None     None      None  ...
# 80  None         None    None  None     None      None  ...
#
#                     job.contractDescription job.duration contact.name  \
# 34     Contrat à durée déterminée - 24 Mois          NaN          NaN
# 65     Contrat à durée déterminée - 24 Mois          NaN          NaN
# 80  Contrat à durée déterminée - 30 Jour(s)          NaN          NaN
#
#    contact.info contact contact.email company.description company.logo  \
# 34          NaN     NaN           NaN                 NaN          NaN
# 65          NaN     NaN           NaN                 NaN          NaN
# 80          NaN     NaN           NaN                 NaN          NaN
#
#    place.departement    month
# 34                35  2020-08
# 65                29  2020-08
# 80                85  2020-08
#
# [3 rows x 41 columns]

# %% [markdown]
# La date de création d'offres d'alternance la plus ancienne étant août 2020, il faut se restreindre dans notre fichier covid à prendre les données qu'à partir de ce mois-ci

# %%
data_covid = pd.read_csv('Data/table-indicateurs-open-data-dep-2021-04-09-20h00.csv')

covid_df = pd.DataFrame(data_covid)
# Out:
# C:\Users\phola\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Pour pouvoir lier les deux fichiers entre eux, on ajoute une colonne mois au fichier covid.

# %%
covid_df['month'] = covid_df['date'].apply(get_month)

# %% [markdown]
# Transformer les dates dans le bon format dans le but de pouvoir appliquer un filtre

# %%
covid_df['date'] = pd.to_datetime(covid_df['date'], format='%Y-%m-%d')

# %%
covid_df[['dep', 'date', 'month', 'tx_incid']]
# Out:
#        dep       date    month   tx_incid
# 0       01 2020-03-18  2020-03        NaN
# 1       01 2020-03-19  2020-03        NaN
# 2       01 2020-03-20  2020-03        NaN
# 3       01 2020-03-21  2020-03        NaN
# 4       01 2020-03-22  2020-03        NaN
# ...    ...        ...      ...        ...
# 39183  976 2021-04-05  2021-04  51.168100
# 39184  976 2021-04-06  2021-04  53.315013
# 39185  976 2021-04-07  2021-04        NaN
# 39186  976 2021-04-08  2021-04        NaN
# 39187  976 2021-04-09  2021-04        NaN
#
# [39188 rows x 4 columns]

# %% [markdown]
# Création d'un filtre pour n'obtenir les dates qu'à partir du 01-08-2021

# %%
mask = (covid_df['date'] > '2020-08-1') & (covid_df['date'] <= '2021-04-11')
filtered_covid_df = covid_df.loc[mask]
data_covid_def = filtered_covid_df[['dep', 'date', 'month', 'tx_incid']]
data_covid_def
# Out:
#        dep       date    month   tx_incid
# 137     01 2020-08-02  2020-08  10.807437
# 138     01 2020-08-03  2020-08  10.198568
# 139     01 2020-08-04  2020-08  10.807437
# 140     01 2020-08-05  2020-08  11.264090
# 141     01 2020-08-06  2020-08  10.959655
# ...    ...        ...      ...        ...
# 39183  976 2021-04-05  2021-04  51.168100
# 39184  976 2021-04-06  2021-04  53.315013
# 39185  976 2021-04-07  2021-04        NaN
# 39186  976 2021-04-08  2021-04        NaN
# 39187  976 2021-04-09  2021-04        NaN
#
# [25351 rows x 4 columns]

# %%
data_covid_def['strdate'] = data_covid_def['date'].apply(str)
data_covid_def.loc[data_covid_def['strdate'].str[-2:] == '15']
# Out:
# <ipython-input-16-1355c08c943c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid_def['strdate'] = data_covid_def['date'].apply(str)
# Empty DataFrame
# Columns: [dep, date, month, tx_incid, strdate]
# Index: []

# %% [markdown]
# Exportation des 2 fichiers en .csv pour enregistrement dans une base de données SQL

# %%
#Export 1ère source de données :

filtered_jobs_df.to_csv('Data/data-offres-alternance.csv', index=False)

#Export 2ème source de données :

data_covid_def.to_csv('Data/data-covid-incidence-dep.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4bec7d07ad38> in <module>
#       1 #Export 1ère source de données :
#       2
# ----> 3 filtered_jobs_df.to_csv('Data/data-offres-alternance.csv', index=False)
#       4
#       5 #Export 2ème source de données :
#
# NameError: name 'filtered_jobs_df' is not defined
